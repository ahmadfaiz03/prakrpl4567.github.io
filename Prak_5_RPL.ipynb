# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadfaiz03/prakrpl4567.github.io/blob/main/Prak_5_RPL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# from google.colab import files
# uploaded = files.upload()

# %%
dataset = pd.read_csv('kc_house_data.csv')

# %%
Y = dataset[['price']]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33717 entries, 0 to 33716
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bedrooms       33717 non-null  int64
#  1   bathrooms      33717 non-null  float64
#  2   sqft_living    33717 non-null  int64
#  3   sqft_lot       33717 non-null  float64
#  4   floors         33717 non-null  float64
#  5   waterfront     33717 non-null  int64
#  6   view           33717 non-null  int64
#  7   condition      33716 non-null  float64
#  8   grade          33716 non-null  float64
#  9   sqft_above     33714 non-null  float64
#  10  sqft_basement  33716 non-null  float64
#  11  yr_built       33716 non-null  float64
#  12  yr_renovated   33716 non-null  float64
#  13  zipcode        33716 non-null  float64
#  14  lat            33716 non-null  float64
#  15  long           33716 non-null  float64
#  16  sqft_living15  33716 non-null  float64
#  17  sqft_lot15     33716 non-null  float64
# dtypes: float64(14), int64(4)
# memory usage: 4.6 MB

# %%
#list our columns
columns = X.columns
columns
# Out:
# Index(['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
#show first 5 records
X.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180    5650.0     1.0           0     0
# 1         3       2.25         2570    7242.0     2.0           0     0
# 2         2       1.00          770   10000.0     1.0           0     0
# 3         4       3.00         1960    5000.0     1.0           0     0
# 4         3       2.00         1680    8080.0     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0        3.0    7.0      1180.0            0.0    1955.0           0.0
# 1        3.0    7.0      2170.0          400.0    1951.0        1991.0
# 2        3.0    6.0       770.0            0.0    1933.0           0.0
# 3        5.0    7.0      1050.0          910.0    1965.0           0.0
# 4        3.0    8.0      1680.0            0.0    1987.0           0.0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# 0  98178.0  47.5112 -122.257         1340.0      5650.0
# 1  98125.0  47.7210 -122.319         1690.0      7639.0
# 2  98028.0  47.7379 -122.233         2720.0      8062.0
# 3  98136.0  47.5208 -122.393         1360.0      5000.0
# 4  98074.0  47.6168 -122.045         1800.0      7503.0

# %%
X.describe()
# Out:
#            bedrooms     bathrooms   sqft_living      sqft_lot        floors  \
# count  33717.000000  33717.000000  33717.000000  3.371700e+04  33717.000000
# mean       3.432008      2.129541   2090.573776  1.482172e+04      1.508436
# std       10.799730      0.770511   1058.263545  4.032203e+04      0.866854
# min        0.000000      0.000000    290.000000  4.758510e+01   -122.073000
# 25%        3.000000      1.750000   1430.000000  5.000000e+03      1.000000
# 50%        3.000000      2.250000   1920.000000  7.525000e+03      1.500000
# 75%        4.000000      2.500000   2560.000000  1.052300e+04      2.000000
# max     1979.000000      8.000000  98075.000000  1.651359e+06      3.500000
#
#          waterfront          view     condition         grade    sqft_above  \
# count  33717.000000  33717.000000  33716.000000  33716.000000  33714.000000
# mean       0.088027      0.775217      3.399365      7.674813   1799.818948
# std       14.813255     99.635756      0.646040      1.176348    832.884076
# min        0.000000      0.000000      1.000000      1.000000    290.000000
# 25%        0.000000      0.000000      3.000000      7.000000   1200.000000
# 50%        0.000000      0.000000      3.000000      7.000000   1570.000000
# 75%        0.000000      0.000000      4.000000      8.000000   2240.000000
# max     2720.000000  18295.000000      5.000000     13.000000   9410.000000
#
#        sqft_basement      yr_built  yr_renovated       zipcode           lat  \
# count   33716.000000  33716.000000  33716.000000  33716.000000  33716.000000
# mean      287.912119   1972.059497     82.511982  98077.902153     47.560063
# std       439.773000     29.665538    397.333030     53.357926      0.138159
# min         0.000000   1900.000000      0.000000  98001.000000     47.155900
# 25%         0.000000   
#
#                sqft_basement  yr_built  yr_renovated   zipcode       lat  \
# price               0.323085  0.057913      0.121819 -0.052565  0.310824
# bedrooms            0.298142  0.152129      0.016125 -0.153831 -0.010997
# bathrooms           0.276329  0.512080      0.044739 -0.203143  0.023843
# sqft_living         0.428051  0.316428      0.051247 -0.201425  0.050096
# sqft_lot            0.020076  0.044125      0.012073 -0.130586 -0.090234
# floors             -0.247750  0.507701     -0.002324 -0.052873  0.051503
# waterfront          0.080262 -0.028488      0.088028  0.036952 -0.013833
# view                0.275526 -0.057542      0.100327  0.087783  0.008578
# condition           0.176641 -0.373245     -0.056688  0.004969 -0.014382
# grade               0.166719  0.448203      0.007544 -0.182458  0.115158
# sqft_above         -0.055131  0.422998      0.019819 -0.263054 -0.004053
# sqft_basement       1.000000 -0.138995      0.069690  0.076728  0.112504
# yr_built           -0.138995  1.000000     -0.226125 -0.338824 -0.145064
# yr_renovated        0.069690 -0.226125      1.000000  0.064174  0.029214
# zipcode             0.076728 -0.338824      0.064174  1.000000  0.268636
# lat                 0.112504 -0.145064      0.029214  0.268636  1.000000
# long               -0.143661  0.399566     -0.066569 -0.564257 -0.136026
# sqft_living15       0.199084  0.320130     -0.002690 -0.281540  0.045260
# sqft_lot15          0.021787  0.058655      0.009346 -0.143368 -0.091329
#
#                    long  sqft_living15  sqft_lot15
# price          0.023373       0.586321    0.081022
# bedrooms       0.135059       0.394856    0.032253
# bathrooms      0.225151       0.565196    0.084882
# sqft_living    0.247057       0.757506    0.181178
# sqft_lot       0.231168       0.141098    0.733813
# floors         0.118524       0.268245   -0.019247
# waterfront    -0.044205       0.080607    0.028876
# view          -0.077942       0.277285    0.079510
# condition     -0.107197      -0.094092    0.002205
# grade          0.197051       0.708025    0.114478
# sqft_above     0.348807       0.731781    0.188662
# sqft_basement -0.143661       0.199084    0.021787
# yr_built       0.399566       0.320130    0.058655
# yr_renovated  -0.066569      -0.002690    0.009346
# zipcode       -0.564257      -0.281540   -0.143368
# lat           -0.136026       0.045260   -0.091329
# long           1.000000       0.340566    0.246764
# sqft_living15  0.340566       1.000000    0.174866
# sqft_lot15     0.246764       0.174866    1.000000

# %%
plt.subplots(figsize=(10,8))
sns.heatmap(dataset.corr())
# Out:
# <Axes: >

# %%
x = X[['sqft_living']]
y = Y

# %%
plt.figure(figsize=(10,6))
plt.xlabel('House Sqft')
plt.ylabel('House Price')
plt.title('Price by Sqft_Living')
plt.scatter(x,y, marker='o', color='g')

# %%
from scipy import stats
sns.set(color_codes=True)

slope, intercept, r_value, p_value, std_err = stats.linregress(dataset['sqft_living'],dataset['price'])

f = plt.figure(figsize=(10,6))
data = dataset[['price','sqft_living']]
ax = sns.regplot(x='sqft_living', y='price', data=data,
                 scatter_kws={"color": "g"},
                 line_kws={'color': 'r', 'label':"y={0:.1f}x+{1:.1f}".format(slope,intercept)})
ax.legend()

# %%
x = X[['sqft_living']]
y = Y

xg = x.values.reshape(-1,1)
yg = y.values.reshape(-1,1)
xg = np.concatenate((np.ones(len(x)).reshape(-1,1), x), axis=1)

def computeCost(x, y, theta):
  m = len(y)
  h_x = x.dot(theta)
  j = np.sum(np.square(h_x - y))*(1/(2*m))
  return j

def gradientDescent(x, y, theta, alpha, iteration):
  print('Running Gradient Descent...')
  j_hist = []
  m = len(y)
  for i in range(iteration):
    j_hist.append(computeCost(x, y, theta))
    h_x = x.dot(theta)
    theta = theta = ((alpha/m) *((np.dot(x.T, (h_x-y)))))
    #theta[0] = theta[0] - ((alpha/m)) *(np.sum((h_x-y)))
  return theta, j_hist

# %%
theta = np.zeros((2,1))
iteration = 2000
alpha = 0.001

theta, cost = gradientDescent(xg, yg, theta, alpha, iteration)
print('Theta found by Gradient Descent; slope = {} and intercept {}'.format(theta[1], theta[0]))
# Out:
# Running Gradient Descent...
# <ipython-input-41-d862001fb325>:11: RuntimeWarning: overflow encountered in square
#   j = np.sum(np.square(h_x - y))*(1/(2*m))
# Theta found by Gradient Descent; slope = [-inf] and intercept [-inf]

# %%
theta.shape
# Out:
# (2, 1)

# %%
plt.figure(figsize=(10,6))
plt.title('$\\theta_0$ = {} , $\\theta_1$ = {}'.format(theta[0], theta[1]))
plt.scatter(x,y, marker='o', color='g')
plt.plot(x,np.dot(x.values, theta.T))
plt.show()

# %%
plt.plot(cost)
plt.xlabel('No. of iterations')
plt.ylabel('Cost')
# Out:
# Text(0, 0.5, 'Cost')

# %%
from scipy import stats

xs = x.iloc[:,0]
ys = y.iloc[:,0]
#xs = np.concatenate((np.ones(len(x)).reshape(-1,1), x), axis=1)

slope, intercept, r_value, p_value, std_err = stats.linregress(xs, ys)

# %%
print('Slope = {} and Intercept = {}'.format(slope, intercept))
print('y = X({}) + {}'.format(slope, intercept))
# Out:
# Slope = 208.0838933521613 and Intercept = 106838.13517797051
# y = X(208.0838933521613) + 106838.13517797051

# %%
plt.figure(figsize=(10,6))
plt.title('$\\theta_0$ = {} , $\\theta_1$ = {}'.format(intercept, slope))
plt.scatter(xs,y, marker='o', color='green')
plt.plot(xs, np.dot(x, slope), 'r')

# %%
xsl = x.values.reshape(-1,1)
ysl = y.values.reshape(-1,1)
xsl = np.concatenate((np.ones(len(xsl)).reshape(-1,1), xsl), axis=1)

from sklearn.linear_model import LinearRegression

slr = LinearRegression()
slr.fit(xsl[:,1].reshape(-1,1), ysl.reshape(-1,1))
y_hat = slr.predict(xsl[:,1].reshape(-1,1))

print('theta[0] = ', slr.intercept_)
print('theta[1] = ', slr.coef_)

thetas = np.array((slr.intercept_, slr.coef_)).squeeze()
# Out:
# theta[0] =  [106838.13517797]
# theta[1] =  [[208.08389335]]
# <ipython-input-49-00b22a709aea>:14: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   thetas = np.array((slr.intercept_, slr.coef_)).squeeze()

# %%
plt.figure(figsize=(10,6))
plt.title('$\\theta_0$ = {} , $\\theta_1$ = {}'.format(thetas[0], thetas[1]))
plt.scatter(xsl[:,1],y, marker='x', color='g')
plt.plot(xsl[:,1], np.dot(xsl, thetas), 'r')
